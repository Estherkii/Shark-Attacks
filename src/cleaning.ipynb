# %% [markdown]
# # CLEANING

# %%
"""
- table
    sales.shape
    sales.columns
    sales.info

- cohesiveness of data
    - sales.duplicated
    - sales.ina().sum()

- values
    sales.dtypes: categorical / qty / str, int, float
    sales.describe, # qtve variables
    sales[col1].value_counts() # frequency of each level of cat, dimensions
    
"""
# Out:
# '\n- table\n    sales.shape\n    sales.columns\n    sales.info\n\n- cohesiveness of data\n    - sales.duplicated\n    - sales.ina().sum()\n\n- values\n    sales.dtypes: categorical / qty / str, int, float\n    sales.describe, # qtve variables\n    sales[col1].value_counts() # frequency of each level of cat, dimensions\n    \n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import pycountry

attacks = pd.read_csv(r"C:\Users\photo\Desktop\Ironhack\projects\project1-shark_attacks\data\attacks.csv", encoding='latin1')

attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#we check data types

attacks.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# I want to know the number of empty cells in attacks
empty_cells = attacks.isna().sum().sum()
empty_cells
# Out:
# 488276

# %%
#deleting null rows

delete_null_rows= attacks.dropna(how='all', inplace=True)
attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#Change name columns at lowercase and delete the space after the words.

attacks.columns = attacks.columns.str.lower().str.rstrip()
attacks
# Out:
#       case number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area                        location     activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
print(attacks.columns)
# Out:
# Index(['case number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal (y/n)', 'time',
#        'species', 'investigator or source', 'pdf', 'href formula', 'href',
#        'case number.1', 'case number.2', 'original order', 'unnamed: 22',
#        'unnamed: 23'],
#       dtype='object')

# %%
columns = ['case number', 'date', 'year', 'type', 'country', 'area', 'location',
       'activity', 'name', 'sex', 'age', 'injury', 'fatal (y/n)', 'time',
       'species', 'investigator or source', 'pdf', 'href formula', 'href',
       'case number.1', 'case number.2', 'original order', 'unnamed: 22',
       'unnamed: 23']

# looping through the columns to fill the entries with NaN values with ""
for column in columns:
    attacks[column] = attacks[column].fillna("")

# %% [markdown]
# # 1. Cleaning "Year"

# %%
#cleaning the value 'year'

values_year = attacks['year'].unique()
values_year
# Out:
# array([2018.0, 2017.0, '', 2016.0, 2015.0, 2014.0, 2013.0, 2012.0, 2011.0,
#        2010.0, 2009.0, 2008.0, 2007.0, 2006.0, 2005.0, 2004.0, 2003.0,
#        2002.0, 2001.0, 2000.0, 1999.0, 1998.0, 1997.0, 1996.0, 1995.0,
#        1984.0, 1994.0, 1993.0, 1992.0, 1991.0, 1990.0, 1989.0, 1969.0,
#        1988.0, 1987.0, 1986.0, 1985.0, 1983.0, 1982.0, 1981.0, 1980.0,
#        1979.0, 1978.0, 1977.0, 1976.0, 1975.0, 1974.0, 1973.0, 1972.0,
#        1971.0, 1970.0, 1968.0, 1967.0, 1966.0, 1965.0, 1964.0, 1963.0,
#        1962.0, 1961.0, 1960.0, 1959.0, 1958.0, 1957.0, 1956.0, 1955.0,
#        1954.0, 1953.0, 1952.0, 1951.0, 1950.0, 1949.0, 1948.0, 1848.0,
#        1947.0, 1946.0, 1945.0, 1944.0, 1943.0, 1942.0, 1941.0, 1940.0,
#        1939.0, 1938.0, 1937.0, 1936.0, 1935.0, 1934.0, 1933.0, 1932.0,
#        1931.0, 1930.0, 1929.0, 1928.0, 1927.0, 1926.0, 1925.0, 1924.0,
#        1923.0, 1922.0, 1921.0, 1920.0, 1919.0, 1918.0, 1917.0, 1916.0,
# ...

# %%
# Removing the trailing period and filter for four-digit years

valid_years = attacks['year'].dropna().astype(str).str.replace(r'\.', '').str.extract(r'(\d{4})')[0]

attacks['year'] = valid_years

# %% [markdown]
# # 2. Cleaning "Species"

# %%
#cleaning the species column

species_unique = attacks['species'].unique()
species_unique
# Out:
# array(['White shark', '', '2 m shark', ..., "12' tiger shark",
#        'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)

# %%
attacks['species'] = attacks['species'].str.lower()

# %%
attacks['species'] = attacks['species'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
def species(input_str):
    
    input_str = input_str.lower() 

    if re.search(r'\bwhite\b', input_str):
        return 'white'
    if re.search(r'\btiger\b', input_str):
        return 'tiger'
    if re.search(r'\blemon\b', input_str):
        return 'lemon'
    if re.search(r'\bbull\b', input_str):
        return 'bull'
    if re.search(r'\b(?:grey|reef)\b', input_str):
        return 'grey reef'
    if re.search(r'\bwobbegong\b', input_str):
        return 'wobbegong'
    if re.search(r'\bshark\b', input_str):
        return 'blacktip'
    if re.search(r'\bgalapagos\b', input_str):
        return 'galapagos'
    if re.search(r'\bnurse\b', input_str):
        return 'nurse'
    if re.search(r'\bspinner\b', input_str):
        return 'spinner'
    if re.search(r'\bporbeagle\b', input_str):
        return 'porbeagle'
    if re.search(r'\bwhitetip\b', input_str):
        return 'whitetip'
    if re.search(r'\bblue\b', input_str):
        return 'blue'
    if re.search(r'\b(?:broadnose|seven|gill)\b', input_str):
        return 'broadnose'
    if re.search(r'\bshovelnose\b', input_str):
        return 'shovelnose'
    if re.search(r'\bsilvertip\b', input_str):
        return 'silvertip'
    if re.search(r'\bronze\b', input_str):
        return 'bronze'
    if re.search(r'\sandbar\b', input_str):
        return 'sandbar'
    
    return 'other'

attacks['species'] = attacks['species'].apply(species)

# %% [markdown]
# #  3. Cleaning "Country"

# %%
#cleaning the value 'country'

country_clean = attacks['country'].unique()

country_clean
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', '', 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
def country(input_str):
    input_str = input_str.lower() 
    
    for country in pycountry.countries:
        if re.search(r'\b{}\b'.format(country.name.lower()), input_str):
            return country.name.upper()

    return 'other'

attacks['country'] = attacks['country'].apply(country)

# %% [markdown]
# #  3. Cleaning "Activity"

# %%
attacks['activity'] = attacks['activity'].str.lower()

# %%
attacks['activity'] = attacks['activity'].str.replace(r'[^a-zA-Z0-9 ]', '', regex=True)

# %%
def activity(input_str):
    if re.search(r'\b(swimming|bathing)\b', input_str):
        return 'swimming'
    if re.search(r'\bfishing\b', input_str, re.IGNORECASE):
        return 'fishing'
    if re.search(r'\bsurfing\b', input_str, re.IGNORECASE):
        return 'surfing'
    if re.search(r'\bboat|yatch|ship\b', input_str, re.IGNORECASE):
        return 'sailing'
    if re.search(r'\bshark\b', input_str, re.IGNORECASE):
        return 'shark interacting'
    if re.search(r'\bdiving|dived?\b', input_str, re.IGNORECASE):
        return 'diving'
    if re.search(r'\b(kayaking|canoe|paddling)\b', input_str):
        return 'kayaking'
    return 'other'

attacks['activity'] = attacks['activity'].apply(activity)

# %% [markdown]
# #  Cleaning "Time"

# %%
def clean_and_standardize_time(time_str):
    # Remove all characters that are not numbers, colons, or 'h'
    cleaned_time = re.sub(r'[^0-9:h]', '', str(time_str))

    # Remove any trailing 'h'
    cleaned_time = cleaned_time.rstrip('h')

    # Handle words or sentences, convert them to NaN
    if re.search(r'\b\w+\b', cleaned_time):
        return np.nan

    # Split the time using 'h' and ':'
    time_parts = re.split(r'[h:]+', cleaned_time)

    if len(time_parts) >= 2:
        # Ensure that there are at least two time parts (HH and MM)
        hh = time_parts[0].zfill(2)
        mm = time_parts[1].zfill(2)
        return f"{hh}:{mm}"
    else:
        return np.nan

# %% [markdown]
# #  Exporting Clean Data

# %%
file_path = r'C:\Users\photo\Desktop\Ironhack\projects\project1-shark_attacks\data\attacks_cleaned.xlsx'

attacks.to_excel(file_path, index=False)
